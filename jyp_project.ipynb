# %%
# INTRODUCTION

# %%
import pandas as pd
import numpy as np
import seaborn 
import csv

# %%
df=pd.read_csv('/c/Users/Dell/Desktop/Phase1_poject/zippedData/bom.movie_gross.csv')
df.head(10)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-1f24e085fd92> in <module>
# ----> 1 df=pd.read_csv('/c/Users/Dell/Desktop/Phase1_poject/zippedData/bom.movie_gross.csv')
#       2 df.head(10)
#
# ...

# %%
df1= pd.read_csv('title.basics.csv')
df1.head(10)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-9eedaa268097> in <module>
# ----> 1 df1= pd.read_csv('title.basics.csv')
#       2 df1.head(10)
#
# ~\Documents\Llian dsf\envs\learn-env\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# ...

# %%
df2 =pd.read_csv('title.ratings.csv')
df2.head(10)

# %%
# Joining two dataframes that is df1and df2
to_concat = [df1, df2]
df3 = pd.concat(to_concat)

# %%
df3.head(10)
# Out:
#       tconst                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
# 5  tt0111414                      A Thin Life                 A Thin Life
# 6  tt0112502                          Bigfoot                     Bigfoot
# 7  tt0137204                  Joe Finds Grace             Joe Finds Grace
# 8  tt0139613                       O Silêncio                  O Silêncio
# 9  tt0144449            Nema aviona za Zagreb       Nema aviona za Zagreb
#
#    start_year  runtime_minutes                      genres  averagerating  \
# 0      2013.0            175.0          Action,Crime,Drama            NaN
# ...

# %%
# Cleaning the data
df3.isna()
# Out:
#        tconst  primary_title  original_title  start_year  runtime_minutes  \
# 0       False          False           False       False            False
# 1       False          False           False       False            False
# 2       False          False           False       False            False
# 3       False          False           False       False             True
# 4       False          False           False       False            False
# ...       ...            ...             ...         ...              ...
# 73851   False           True            True        True             True
# 73852   False           True            True        True             True
# 73853   False           True            True        True             True
# 73854   False           True            True        True             True
# 73855   False           True            True        True             True
#
#        genres  averagerating  numvotes
# 0       False           True      True
# ...
